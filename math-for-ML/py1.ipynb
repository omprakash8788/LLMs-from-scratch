# %%
from turtle import *
forward(100)
shape('turtle')
right(45)
forward(150)

# %%
from turtle import *
shape('turtle')
for i in range(4):
 forward(100)
 right(90)

# %%
def square(sidelength):
 for i in range(4):
  forward(sidelength)
  right(90)
square(87)
