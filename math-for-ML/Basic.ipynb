# %% [markdown]
# ## Basic math

# %% [markdown]
# * Let do some time pass math problem

# %%
a = 5
b=8
addBoth = a + b
print(addBoth)
# Out:
# 13

# %% [markdown]
# * Sub

# %%
a = 5
b=8
subBoth = b - a
print(subBoth)
# Out:
# 3

# %% [markdown]
# * Mul

# %%
subBoth

# %%
a = 5
b=8
mulBoth = b *  a
print(mulBoth)
# Out:
# 40

# %% [markdown]
# * Div

# %%
a = 5
b=8
subBoth = b / a
print(subBoth)
# Out:
# 1.6
